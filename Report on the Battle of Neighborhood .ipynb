# %% [markdown]
# # Introduction and Business Problem

# %% [markdown]
# This is the final project in the course by coursera. This project is purely based on real life data science scenario.

# %% [markdown]
# In Japan, Tokyo is one of the popular metropolitan area. Infact, in Asia Tokyo is ranked as 1st in global economic power. It has wonderful culture and living standards. I beleive it is a perfect place to start a new business. For this project my focus will be on launching a designer boutique in most busy wards in Tokyo.

# %% [markdown]
#  In big cities like Tokyo , Clothing and styling are important factors which need to be considered in order to form a nice personality. Therefore, there will be huge scope of opportunity in such field. In this project we will go through factors like benefits and losses of opening a designer boutique in busy wards of Tokyo. We will consider the most frequent visit of people in order to understand the popularity of venues among visitors which will help us in understanding which area's probablity is most of getting visitors everyday.

# %% [markdown]
# This project will be helpful for a designer who wants to open a business in busy wards of Tokyo city. We will analyze popular venues of Tokyo city wards  and understand areas where there is less competition for a designer boutique store.

# %% [markdown]
# Profit margin for retail designer boutique generally within a range of 4 percent to 13 percent. Markups also seems high as compared to Cost of goods sold and other variable costs. In large cities like Tokyo the retail industry is not only driven by the factors like price or designers, but the main factors are culture and traditions. Also Land pricing, venues and brand name. In This project our concentration area will be venue of the designer store. As the store will be open by a designer it has to be in a venue where most of the people are willing to pay for designer clothing. Our target segment will be people who are prone to shop designer clothes.
# Correct venue of designer store will attract more customers. We will concentrate on 5 most busiest wards of Tokyo in order to anakyzing what will be the perfect venue for designer store.

# %% [markdown]
# Target segment : Our Target segment is basically the foot traffic in the popular venues of Tokyo city. As there are lot of companies near by we can say many business professionals or workers may visit designer boutique. Also, the students, housewives and other people who likes to roam around  the city and explore different stores may visit designer boitique.

# %% [markdown]
# # Source of Data

# %% [markdown]
# ## Webscrapping of the data through Wikipedia

# %% [markdown]
# I have web scrapped data from https://en.wikipedia.org/wiki/Special_wards_of_Tokyo wikipedia page to get all 23 wards of Tokyo city like 5 bouroughs of NYC. In order to webscrape and pull data from wikipedia i have used libraries like BeautifulSoup and Request. I have cleaned the data by readimg html and dropping columns which are not required. Converted the Major districts column in string to get one major district from each ward.
#
# Another step is to acquire geo cordinates of each ward. In order to pull that i have used geopy library. To merge the data i have used lambda and converted the coordinates  into strings and then spilt them into two coloumns as latitude and longitude.

# %% [markdown]
# Next step is to obtain the avergae price for each ward in JPY. In order to get that i  have scrapped another wikidpedia page 'https://utinokati.com/en/details/land-market-value/area/Tokyo/' through beautifuld soup library and request and  used merge to merge both dataframes.

# %% [markdown]
# # Methodology

# %% [markdown]
# ## Use of Foursquare API

# %% [markdown]
# After getting the final dataframe of 23 wards with geo cordinates , i have selected first 5 wards to analyze near by venues of each 5 wards. I have selected ward_list = ['Chiyoda', 'Minato', 'Shinjuku', 'Sumida', 'Shinagawa'] as my ward list. Its averge land price and  cordinated are defined in this ward_list dataframe. The coordinates will help us  in getting the near by popular venues of each wards's major_districts. I have used folium libarry to view these 2 wards in a geographical map.

# %% [markdown]
# Foursquare is an API which help us to get near by venues of major districts in each 5 wards in Tokyo city. in radius of 2000 and with limit of 100 i got 5 major district's near by venues i.e.
#
# Nagatachō
# Odaiba
# Shinjuku
# Kinshichō
# Shinagawa

# %% [markdown]
# Again to visulaize how many boutiques are there in the area i have used folum library to view the geopgraphical figure. There are 19 unique categories in this 5 districts. 33 are boutiques and 150 are common clothing store. Men's store are 28 and Women' store are 24

# %% [markdown]
# we need top 10 categories, in order to get that i have plotted a figure which is a vilin figure plot for different stores at major districts. As we further analyze we notice that Shinjuku has most unqiuye category stores.

# %% [markdown]
# # k means clustering

# %% [markdown]
# With K means clustering and using those cluser labeles we will create a mao which shows all districts which has most clothing store and boutiques.

# %% [markdown]
# Cluster labels will define each district and gives us the idea which is the most common venue in that particular major district.

# %% [markdown]
# # Result

# %% [markdown]
# As per the clusters we can see that as there are less no. of boutiques in Kinshichō and Shinagawa,which means if a designer boutique is launch in this particular area there will be less competition. Chance of getting notice and earning profitablity in this sector will be high for new launched boutique.

# %% [markdown]
# # Recommendation

# %% [markdown]
# I recommend analzying the target audience more in this 5 major districts to understand prfitability . I have gone through the average land pricing which help us to know which area has least averge price in JPY. This is only one factor to be considered to open a new business in Tokyo city. We have to consider marketing factors and factors like preference of people, culture and standrad of living data .

# %% [markdown]
# # Conclusion

# %% [markdown]
# Hence, there are three major districts in which most of the clothing store and Boutique exist and as the designer boutiques are less in no. we can predict a good possability of new designer boutiue in Shinagawa, Nagatachō and Odaiba. The Boutiques are either 3rd most or 2nd most common venues which means the foot traffic in Tokyo's major dictricts are interested in looking at the boutique to make new purchases. By looking at the clusters we can figure out that all the major districts's are crowded by clothing store or shoe store and there are less designer boutiques therefore a designer boutique for both men and women can be a profitable business to launch.
